# %% [markdown]
# # Let's study for Jeopardy!

# %% [markdown]
# Hi! Thanks for reading this!
#
# In mid-February 2020, I got the call of a lifetime -- I was going to be on Jeopardy! Since I was young, I've been besting my peers at trivia. Soon, I was besting my parents too. Getting on Jeopardy! was an absolute dream for me.
#
# Then everything changed when the COVID-19 attacked.
#
# The week after that call, I was told that filming was taking a pause as they figured out this whole pandemic business. Okay, I thought, that gives me time to study. Plus, I didn't turn my contestant story document in on time, so really, this was a win.
#
# In April 2021, I got another call from the Jeopardy! producers, inviting me to film. At that time, I wasn't vaccinated. I work at a science non-profit with public-health adjacent projects, so I couldn't in good faith fly to Cali just to be on a game show.
#
# Well, in late July 2021, I got the call again. Now that I am vaccinated, I might as well! Of course, as my luck would have it, as I'm prepping for my television debut, Matt Amodio is in the midst of a legendary run. I am hoping someone [Nancy Zergs](https://j-archive.com/showplayer.php?player_id=120) him before I film, but in the event that doesn't happen, I'm doing my damnedest to beat him.
#
# **I've built this little app to do a few things:**
#     - Give me 10 top-level difficult questions at a time. Top-level difficulty means the $1000 and $2000 clues.
#     - Bombard me with sports and geography trivia (two categories in which I am extremely lacking)
#     - Simulate the bulk of a game with 12 categories chosen at random.
#     - Track my progess in my trouble categories.
#
# I'm *planning* on winning 5 games of Jeopardy! If that doesn't happen, maybe you'll do it. Feel free to use this little app to get some practice in. If you think it helped you, [please shoot me an email!](mailto:k4thrynkohn@gmail.com)
#
# Oh, and a huge shout out to Luke Lavin, who built out the API this program is using. This is my first time using an API and he's been a huge help with his [clear documentation and nice looking website](https://cluebase.readthedocs.io/en/latest/). Please send all kudos to him!

# %%
import requests
import json
import numpy as np
import pandas as pd
from random import randint

# %% [markdown]
# **LEVEL 5 DIFFICULTY QS**

# %%
url = "http://cluebase.lukelav.in/clues/random?limit=10&difficulty=5"

r = requests.get(url)

cluebase = json.loads(r.text)

clue_list = []
for i in range(len(cluebase['data'])):
    category = cluebase['data'][i]['category']
    value = cluebase['data'][i]['value']
    clue = cluebase['data'][i]['clue']
    response = cluebase['data'][i]['response']
    
    question = {
        'Category':category,
        'Value':value,
        'Clue': clue,
        'Response':response
    }
    clue_list.append(question)

for i in range(len(clue_list)):
    print(clue_list[i])
# Out:
# {'Category': 'I THEE WED', 'Value': 1000, 'Clue': '2005:Melania Knauss', 'Response': 'Donald Trump'}
# {'Category': 'COMPLETES THE NONFICTION TITLE', 'Value': 1000, 'Clue': 'A Pulitzer Prize-winning "Biography of Cancer": "The Emperor of All ____"', 'Response': 'maladies'}
# {'Category': 'INNS', 'Value': 1000, 'Clue': 'The Red Horse Inn in Sudbury, Massachusetts was the model for Longfellow\'s "Tales of" this "Inn"', 'Response': 'the Wayside Inn'}
# {'Category': 'WANNA BET?', 'Value': 1000, 'Clue': "In this fancy-schmancy card game, it's just who gets closest to a total of 9 who wins", 'Response': 'baccarat'}
# {'Category': 'CELEBRITY QUOTES', 'Value': 1000, 'Clue': 'Tallest of the Nerds, I\'m now operating on "ER"', 'Response': 'Anthony Edwards'}
# {'Category': 'THE BRITISH ARE COMING!', 'Value': 1000, 'Clue': 'Then-session guitarist Jimmy Page played on this 1-named guy\'s "Sunshine Superman"', 'Response': 'Donovan'}
# {'Category': 'THE 1990s', 'Value': 1000, 'Clue': "In December 1995 2 of this country's former presidents, Chun Doo Hwan & Roh Tae Woo, were indicted", 'Response': 'South Korea'}
# {'Category': 'MULTIPLE DIAGNOSES', 'Value': 1000, 'Clue': 'The fever clearly indicates mono--oops, colitis.  No, TB.  Of course, this bacterial ailment aka septic sore throat', 'Response': 'strep throat'}
# {'Category': 'TRAVEL U.S.A.', 'Value': 1000, 'Clue': 'Kilgore College in this state has a museum devoted to the Kilgore Rangerettes Drill team', 'Response': 'Texas'}
# {'Category': 'MISS MANNERS', 'Value': 1000, 'Clue': 'Miss Manners says these leaves are "claustrophobic" & hate "being stuffed into little bags", so serve the "loose" type', 'Response': 'tea (leaves)'}

# %% [markdown]
# **SPORTS & GEOGRAPHY**

# %%
sports_only = requests.get("http://cluebase.lukelav.in/clues/random?category=sports&limit=10")

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(sports_only.json())
# Out:
# {
#     "data": [
#         {
#             "category": "SPORTS",
#             "clue": "2 types of competition in this sport are \"speed\" & \"figure\"",
#             "daily_double": false,
#             "game_id": 6086,
#             "id": 355054,
#             "response": "skating",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "SPORTS",
#             "clue": "Men from this sport named Male Athlete of the Year by the AP include Ben Hogan & Lee Trevino",
#             "daily_double": false,
#             "game_id": 5359,
#             "id": 312993,
#             "response": "golf",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "SPORTS",
#             "clue": "Of running, athletics, or track & field, term for track & field in Britain",
#             "daily_double": false,
#             "game_id": 6098,
#             "id": 355702,
#             "response": "athletics",
#             "round": "J!",
#             "value": 600
#         },
#         {
#             "category": "SPORTS",
#             "clue": "With a 1996-97 salary of $30 million, he's the NBA's highest-paid player",
#             "daily_double": false,
#             "game_id": 5153,
#             "id": 300878,
#             "response": "Michael Jordan",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "SPORTS",
#             "clue": "In soccer, it's nudging the ball forward with your feet; in basketball, it's bouncing it with your hands",
#             "daily_double": false,
#             "game_id": 5865,
#             "id": 342530,
#             "response": "dribbling",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "SPORTS",
#             "clue": "He's the only Chicago Bulls player named Rookie of the Year",
#             "daily_double": false,
#             "game_id": 5180,
#             "id": 302471,
#             "response": "Michael Jordan",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "SPORTS",
#             "clue": "If you can \"spare\" the time in St. Louis, you might \"strike out\" & visit the hall of fame for this sport",
#             "daily_double": false,
#             "game_id": 5407,
#             "id": 315803,
#             "response": "bowling",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "SPORTS",
#             "clue": "After 36 seasons in this stadium named for a U.S. senator, the Redskins moved to a new facility in Sept. 1997",
#             "daily_double": false,
#             "game_id": 4841,
#             "id": 282702,
#             "response": "RFK (Robert F. Kennedy) Stadium",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "SPORTS",
#             "clue": "For it's auction of game-used collectibles, the NFL uses this popular internet auction site",
#             "daily_double": false,
#             "game_id": 3567,
#             "id": 208113,
#             "response": "eBay",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "SPORTS",
#             "clue": "In the 1980s, this Spaniard became the youngest golfer to win the Masters & helped Europe win 3 Ryder Cups",
#             "daily_double": false,
#             "game_id": 5246,
#             "id": 306322,
#             "response": "Seve Ballesteros",
#             "round": "J!",
#             "value": 800
#         }
#     ],
#     "status": "success"
# }

# %%
geo_only = requests.get("http://cluebase.lukelav.in/clues/random?category=geography&limit=10")

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(geo_only.json())
# Out:
# {
#     "data": [
#         {
#             "category": "GEOGRAPHY",
#             "clue": "In Egypt & Algeria, some areas of this desert are below sea level",
#             "daily_double": false,
#             "game_id": 5190,
#             "id": 303088,
#             "response": "Sahara",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "Montego Bay has been called the resort capital of this Caribbean island",
#             "daily_double": false,
#             "game_id": 5092,
#             "id": 297330,
#             "response": "Jamaica",
#             "round": "DJ!",
#             "value": 2000
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "The rock & fortress of Masada are found by this sea's shore",
#             "daily_double": false,
#             "game_id": 6062,
#             "id": 353685,
#             "response": "the Dead Sea",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "This country borders every other country in South America except Ecuador & Chile",
#             "daily_double": false,
#             "game_id": 5092,
#             "id": 297325,
#             "response": "Brazil",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "(Jimmy of the Clue Crew shows the Andes on the monitor.) A small stream in Peru's Andes flows into the Apurimac, becoming a source of this river that some 4,000 miles later flows into the Atlantic",
#             "daily_double": false,
#             "game_id": 265,
#             "id": 15090,
#             "response": "the Amazon",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "This desert is home to Africa's Bushmen",
#             "daily_double": false,
#             "game_id": 6245,
#             "id": 363757,
#             "response": "the Kalahari",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "The northern end of this country's largest lake, Lake Garda in the Po Valley, once belonged to Austria",
#             "daily_double": false,
#             "game_id": 968,
#             "id": 55719,
#             "response": "Italy",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "Capt. Cook discovered this coral structure off Australia when he ran his ship into it",
#             "daily_double": false,
#             "game_id": 6172,
#             "id": 359820,
#             "response": "Great Barrier Reef",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "The Thar Desert covers over 75,000 square miles in the Indian state of Rajasthan & in this country",
#             "daily_double": false,
#             "game_id": 5275,
#             "id": 308057,
#             "response": "Pakistan",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "GEOGRAPHY",
#             "clue": "The ownership of the islands of Tierra del Fuego is shared by these 2 nations",
#             "daily_double": false,
#             "game_id": 3119,
#             "id": 181699,
#             "response": "Chile & Argentina",
#             "round": "DJ!",
#             "value": 1200
#         }
#     ],
#     "status": "success"
# }

# %% [markdown]
# **Let's play a game**

# %%
val = randint(0,1987)
url = f"http://cluebase.lukelav.in/categories?limit=12&offset={val}"

r = requests.get(url)

categories = json.loads(r.text)

cat_list = []


for i in range(len(categories['data'])):
    category = categories['data'][i]['category']
    cat_list.append(category)

cat_lower = []
for cat in cat_list:
    catlow = cat.lower()
    cat_lower.append(catlow)
print(cat_lower)

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

for cat in cat_lower:
    cat2 = requests.get(f"http://cluebase.lukelav.in/clues/random?category={cat}&limit=6")
    jprint(cat2.json())
# Out:
# ['law & order', 'utah', 'pop music pairings', 'isms', '6-syllable words', 'vice-presidents', 'beauty', 'we mean business', 'kid lit', 'anagrammed musicals', 'trademarks', "what's up, doc?"]
# {
#     "data": [],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "UTAH",
#             "clue": "Each May 10, a reenactment of the driving of the Golden Spike takes place at a summit near this point of the same name",
#             "daily_double": false,
#             "game_id": 3921,
#             "id": 228899,
#             "response": "Promontory",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "UTAH",
#             "clue": "Glen Canyon Dam, completed in 1964, created this 186-mile-long lake on the Colorado River",
#             "daily_double": false,
#             "game_id": 3921,
#             "id": 228917,
#             "response": "Lake Powell",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "UTAH",
#             "clue": "In August in Salt Lake City there's a festival for this Mideastern dance (& you thought Utahans were a staid bunch...)",
#             "daily_double": false,
#             "game_id": 3658,
#             "id": 213497,
#             "response": "belly dancing",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "UTAH",
#             "clue": "The Ski resort town of Park City is the home of this film festival sponsored by Robert Redford's organization",
#             "daily_double": false,
#             "game_id": 3921,
#             "id": 228893,
#             "response": "Sundance",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "UTAH",
#             "clue": "The state's largest ski area, Park City, is on the eastern slopes of this range of the Rockies",
#             "daily_double": false,
#             "game_id": 5713,
#             "id": 333814,
#             "response": "Wasatch",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "UTAH",
#             "clue": "Record speeds of more than 600 MPH have been reached at the International Speedway here",
#             "daily_double": false,
#             "game_id": 5713,
#             "id": 333804,
#             "response": "Bonneville Salt Flats",
#             "round": "J!",
#             "value": 600
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "...& the Sunshine Band",
#             "daily_double": false,
#             "game_id": 3668,
#             "id": 214071,
#             "response": "KC",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "____ & Tennille",
#             "daily_double": false,
#             "game_id": 3596,
#             "id": 209812,
#             "response": "The Captain",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "...& the Sunshine Band",
#             "daily_double": false,
#             "game_id": 4444,
#             "id": 259610,
#             "response": "KC",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "...& the Crickets",
#             "daily_double": false,
#             "game_id": 4444,
#             "id": 259592,
#             "response": "Buddy Holly",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "...& the New Power Generation",
#             "daily_double": false,
#             "game_id": 4444,
#             "id": 259598,
#             "response": "Prince",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "POP MUSIC PAIRINGS",
#             "clue": "...& Herb",
#             "daily_double": false,
#             "game_id": 4444,
#             "id": 259604,
#             "response": "Peaches",
#             "round": "J!",
#             "value": 600
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "ISMs",
#             "clue": "It's the practice of preparing for war by retreating to remote areas & storing food & weapons",
#             "daily_double": false,
#             "game_id": 5009,
#             "id": 292440,
#             "response": "survivalism",
#             "round": "DJ!",
#             "value": 2000
#         },
#         {
#             "category": "ISMs",
#             "clue": "Late 19th century movement that characterizes the work seen here",
#             "daily_double": false,
#             "game_id": 3554,
#             "id": 207314,
#             "response": "Impressionism",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "ISMs",
#             "clue": "One of these can be \"of fire\" or by immersion in water during a religious rite",
#             "daily_double": false,
#             "game_id": 4467,
#             "id": 260995,
#             "response": "Baptism",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "ISMs",
#             "clue": "Manorialism was the economic basis of this system of political & military obligation in the Middle Ages",
#             "daily_double": false,
#             "game_id": 4467,
#             "id": 261007,
#             "response": "Feudalism",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "ISMs",
#             "clue": "News gathering & reporting; the University of Missouri had the USA's first school of it",
#             "daily_double": false,
#             "game_id": 3554,
#             "id": 207320,
#             "response": "journalism",
#             "round": "J!",
#             "value": 600
#         },
#         {
#             "category": "ISMs",
#             "clue": "Copying your term paper directly out of an encyclopedia",
#             "daily_double": false,
#             "game_id": 4467,
#             "id": 260989,
#             "response": "plagiarism",
#             "round": "DJ!",
#             "value": 400
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "In this type of complex, one has a persistent sense of inadequacy or a tendency to self-diminishment",
#             "daily_double": false,
#             "game_id": 1272,
#             "id": 73418,
#             "response": "inferiority",
#             "round": "J!",
#             "value": 400
#         },
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "In \"The Bells\" Poe used this long word meaning the ringing of bells",
#             "daily_double": false,
#             "game_id": 671,
#             "id": 38702,
#             "response": "tintinnabulation",
#             "round": "DJ!",
#             "value": 2000
#         },
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "To have an insufficient amount of startup cash for a business enterprise",
#             "daily_double": false,
#             "game_id": 1773,
#             "id": 102589,
#             "response": "undercapitalize",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "In 2006 the U.S. Army & the Marine Corps released a new field manual for this word, dealing with rebellion",
#             "daily_double": false,
#             "game_id": 1990,
#             "id": 115309,
#             "response": "counterinsurgency",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "From the Latin for \"cannot grasp\" comes this word meaning \"impossible to understand\"",
#             "daily_double": false,
#             "game_id": 1990,
#             "id": 115303,
#             "response": "incomprehensible",
#             "round": "DJ!",
#             "value": 1200
#         },
#         {
#             "category": "6-SYLLABLE WORDS",
#             "clue": "Both Betsy Ross & Dolley Madison were disowned by the Quakers for marrying men from this denomination",
#             "daily_double": false,
#             "game_id": 1272,
#             "id": 73436,
#             "response": "Episcopalian",
#             "round": "J!",
#             "value": 1000
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "V.P. who also served as ambassador to U.N. & director of the C.I.A.",
#             "daily_double": false,
#             "game_id": 6311,
#             "id": 367217,
#             "response": "George Bush",
#             "round": "DJ!",
#             "value": 2000
#         },
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "The only vice president from California",
#             "daily_double": false,
#             "game_id": 6243,
#             "id": 363664,
#             "response": "Richard Nixon",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "Later vice president, he 1st visited the capital while leading Boy Scouts from Minnesota",
#             "daily_double": false,
#             "game_id": 6189,
#             "id": 360731,
#             "response": "Hubert Humphrey",
#             "round": "J!",
#             "value": 600
#         },
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "Though V.P. & president, he was never elected to either post",
#             "daily_double": false,
#             "game_id": 6311,
#             "id": 367204,
#             "response": "Gerald Ford",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "Jefferson's 1st vice president, he was officially divorced for adultery on the day he died",
#             "daily_double": false,
#             "game_id": 6189,
#             "id": 360736,
#             "response": "Aaron Burr",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "VICE-PRESIDENTS",
#             "clue": "Some unkindly called this vice president & successor \"Nixon's revenge\"",
#             "daily_double": false,
#             "game_id": 6189,
#             "id": 360720,
#             "response": "Ford",
#             "round": "J!",
#             "value": 200
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "BEAUTY",
#             "clue": "Short masculine nickname that's also a woman's short hair style",
#             "daily_double": false,
#             "game_id": 4835,
#             "id": 282354,
#             "response": "Bob",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "BEAUTY",
#             "clue": "This substance injected to fill out lips is purified connective tissue from cows",
#             "daily_double": false,
#             "game_id": 5003,
#             "id": 292069,
#             "response": "Collagen",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "BEAUTY",
#             "clue": "Edmund Burke's 1757 work \"On the Sublime and Beautiful\" is a landmark in this, the philosophy of beauty",
#             "daily_double": false,
#             "game_id": 871,
#             "id": 50157,
#             "response": "aesthetics",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "BEAUTY",
#             "clue": "Cosmetic overapplied in the photo seen here:",
#             "daily_double": false,
#             "game_id": 4835,
#             "id": 282360,
#             "response": "Blue eye shadow",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "BEAUTY",
#             "clue": "\"Because I'm Worth It\" is a slogan of this line of cosmetics from Paris",
#             "daily_double": false,
#             "game_id": 4835,
#             "id": 282366,
#             "response": "L\\'Oreal",
#             "round": "DJ!",
#             "value": 1200
#         },
#         {
#             "category": "BEAUTY",
#             "clue": "The bird seen here, or the first name of actress Cates",
#             "daily_double": false,
#             "game_id": 4163,
#             "id": 243155,
#             "response": "Phoebe",
#             "round": "DJ!",
#             "value": 1600
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "Revealing some of its wares, Nabisco was originally the \"National\" this \"Company\"",
#             "daily_double": false,
#             "game_id": 989,
#             "id": 56912,
#             "response": "Biscuit",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "In 1901 John Queeny founded chemical company Monsanto to make this synthetic sweetener",
#             "daily_double": false,
#             "game_id": 479,
#             "id": 27484,
#             "response": "saccharin",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "In 1792 the NYSE was established when businessmen came to an agreement under a buttonwood tree on this street",
#             "daily_double": false,
#             "game_id": 3383,
#             "id": 197271,
#             "response": "Wall Street",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "You can get a \"Zestimate\" of a home's value or search for a new house at this website",
#             "daily_double": false,
#             "game_id": 479,
#             "id": 27490,
#             "response": "Zillow",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "The license to sell the goods of a company, such as McDonald's, in a designated territory",
#             "daily_double": false,
#             "game_id": 989,
#             "id": 56894,
#             "response": "a franchise",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "WE MEAN BUSINESS",
#             "clue": "Introduced in 1948, Glidden's Spread  Satin is a type of this",
#             "daily_double": false,
#             "game_id": 2675,
#             "id": 155550,
#             "response": "paint",
#             "round": "J!",
#             "value": 200
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "KID LIT",
#             "clue": "In a 1964 book by this man, the mysterious Willy Wonka owns a unique chocolate factory",
#             "daily_double": false,
#             "game_id": 3203,
#             "id": 186624,
#             "response": "Roald Dahl",
#             "round": "DJ!",
#             "value": 1200
#         },
#         {
#             "category": "KID LIT",
#             "clue": "In a Lewis Carroll story, this young girl has wondrous \"Adventures in Wonderland\"",
#             "daily_double": false,
#             "game_id": 4330,
#             "id": 252909,
#             "response": "Alice",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "KID LIT",
#             "clue": "This Belgian cartoon boy with a dog named Snowy is an amateur detective",
#             "daily_double": false,
#             "game_id": 4330,
#             "id": 252927,
#             "response": "Tintin",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "KID LIT",
#             "clue": "A game of hide & seek leads Peter, Susan, Edmund & Lucy into this land that's \"always winter & never Christmas\"",
#             "daily_double": false,
#             "game_id": 2980,
#             "id": 173399,
#             "response": "Narnia",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "KID LIT",
#             "clue": "This 3-letter Kipling lad goes on a Himalayan journey with a Tibetan lama",
#             "daily_double": false,
#             "game_id": 2980,
#             "id": 173423,
#             "response": "Kim",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "KID LIT",
#             "clue": "Leroy is the real first name of the boy detective with this bookish nickname",
#             "daily_double": false,
#             "game_id": 2980,
#             "id": 173405,
#             "response": "Encyclopedia Brown",
#             "round": "J!",
#             "value": 400
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "\"A LID MAY FRY\"",
#             "daily_double": false,
#             "game_id": 4559,
#             "id": 266294,
#             "response": "My Fair Lady<",
#             "round": "J!",
#             "value": 600
#         },
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "Lerner & Loewe's Scotstravaganza:\"A Goon Bird\"",
#             "daily_double": false,
#             "game_id": 4503,
#             "id": 263097,
#             "response": "\"Brigadoon\"",
#             "round": "J!",
#             "value": 600
#         },
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "\"STEW RIDES TOYS\"",
#             "daily_double": false,
#             "game_id": 4559,
#             "id": 266300,
#             "response": "West Side Story<",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "\"Itchy Sweater\"",
#             "daily_double": false,
#             "game_id": 4647,
#             "id": 271427,
#             "response": "Sweet Charity<",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "\"Go Sin Amiss\"",
#             "daily_double": false,
#             "game_id": 4607,
#             "id": 269120,
#             "response": "Miss Saigon<",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "ANAGRAMMED MUSICALS",
#             "clue": "\"CLAM TOE\"",
#             "daily_double": false,
#             "game_id": 4559,
#             "id": 266282,
#             "response": "Camelot<",
#             "round": "J!",
#             "value": 200
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "TRADEMARKS",
#             "clue": "This 3M brand dates to 1930; it became \"Magic Tape\" in 1961",
#             "daily_double": false,
#             "game_id": 1119,
#             "id": 64441,
#             "response": "Scotch",
#             "round": "J!",
#             "value": 200
#         },
#         {
#             "category": "TRADEMARKS",
#             "clue": "This contest was first held in 1949 to celebrate Pillsbury's 80th birthday",
#             "daily_double": false,
#             "game_id": 1734,
#             "id": 100272,
#             "response": "a Pillsbury bake-off",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "TRADEMARKS",
#             "clue": "Next time you go diving in one of these large trash bins, remember it's trademarked",
#             "daily_double": false,
#             "game_id": 1370,
#             "id": 79101,
#             "response": "Dumpster",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "TRADEMARKS",
#             "clue": "It's Kawasaki's trademarked brand of 1- and 3-passenger boats that are ridden like motorcycles",
#             "daily_double": false,
#             "game_id": 1119,
#             "id": 64464,
#             "response": "Jet Skis",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "TRADEMARKS",
#             "clue": "This 5-word boast is the trademark of Ringling Brothers Barnum and Bailey Circus",
#             "daily_double": false,
#             "game_id": 1370,
#             "id": 79118,
#             "response": "The Greatest Show on Earth",
#             "round": "DJ!",
#             "value": 1600
#         },
#         {
#             "category": "TRADEMARKS",
#             "clue": "This gum brand gets its name from a Spanish word for \"gum\"",
#             "daily_double": false,
#             "game_id": 1119,
#             "id": 64453,
#             "response": "Chiclets",
#             "round": "J!",
#             "value": 600
#         }
#     ],
#     "status": "success"
# }
# {
#     "data": [
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "Your redness & flushing are characteristic of this skin disease sometimes inaccurately called adult acne",
#             "daily_double": false,
#             "game_id": 1655,
#             "id": 95724,
#             "response": "rosacea",
#             "round": "J!",
#             "value": 800
#         },
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "This German bacteriologist discovered that Salvorsan was the \"magic bullet\" to treat syphilis",
#             "daily_double": false,
#             "game_id": 4484,
#             "id": 262016,
#             "response": "Paul Ehrlich",
#             "round": "DJ!",
#             "value": 2000
#         },
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "You're at risk for peritonitis, so I'll perform this surgery, done 300,000 times a year in the U.S.",
#             "daily_double": false,
#             "game_id": 3647,
#             "id": 212840,
#             "response": "an appendectomy",
#             "round": "J!",
#             "value": 1000
#         },
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "In 1899, along with his 2 sons, he founded St. Marys's Hospital in Rochester, Minnesota",
#             "daily_double": false,
#             "game_id": 4484,
#             "id": 261994,
#             "response": "William Mayo",
#             "round": "DJ!",
#             "value": 400
#         },
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "In 1798 he published \"An Inquiry into...a Disease by the Name of Cow Pox\"",
#             "daily_double": false,
#             "game_id": 4484,
#             "id": 262000,
#             "response": "Edward Jenner",
#             "round": "DJ!",
#             "value": 800
#         },
#         {
#             "category": "WHAT'S UP, DOC?",
#             "clue": "Your aching jaw might be caused by bruxism, or doing this while you sleep",
#             "daily_double": false,
#             "game_id": 3647,
#             "id": 212828,
#             "response": "grinding your teeth",
#             "round": "J!",
#             "value": 600
#         }
#     ],
#     "status": "success"
# }
